# %% [raw]
# Dawit Reda
# ID#10189420
# Module 6 Data Visualization
# Programming for the Data Science
# Submitted to Dr. Daniel Wu

# %% [markdown]
# # Data Visualization

# %%
#import all important libraries (someof them have been installed lately)
import numpy as np
import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt
from statistics import *
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.tools as tls

# %% [raw]
# 6.1 Read data from the provided file into a DataFrame read_csv

# %%
#load data from local
file_name =  r'C:\Users\redadg\Desktop\Old Desktop\MS\Programming for data science\Assignmnets\Module 6\MCIS540_M6x_Data.csv'

#Read data from the provided file into a DataFrame read_csv
df = pd.read_csv(file_name)

# Drop rows with any empty cells
df =df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %% [raw]
# 6.2 Print the first 5 elements of your DataFrame using the command head(). How many features are there and what are their types (e.g., numeric, nominal)?

# %%
#Print the first 5 elements of your DataFrame using the command head()
print(df.head())
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 2           4.9          3.0           1.4          0.2  Iris-setosa
# 4           4.7          3.2           1.3          0.2  Iris-setosa
# 6           4.6          3.1           1.5          0.2  Iris-setosa
# 8           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#How many features are there 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 298
# Data columns (total 5 columns):
# Sepal Length    150 non-null float64
# Sepal Width     150 non-null float64
# Petal Length    150 non-null float64
# Petal Width     150 non-null float64
# Name            150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
# what are their types
df.dtypes
# Out:
# Sepal Length    float64
# Sepal Width     float64
# Petal Length    float64
# Petal Width     float64
# Name             object
# dtype: object

# %%
#Print out the shape
df.shape
# Out:
# (150, 5)

# %%
#To see statistical details of the dataset, we can use describe():
#this will display minimum value, maximum value, mean, standard deviation, count, and 25:50:75% percentiles
df.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# determine Range: which is the difference between the lowest and highest value of each of the datasets
print('The range of Sepal Length is :', (df['Sepal Length'].max() - df['Sepal Length'].min()))
print('The range of Sepal Width is :', (df['Sepal Width'].max() - df['Sepal Width'].min()))
print('The range of Sepal Length is :', (df['Petal Length'].max() - df['Petal Length'].min()))
print('The range of Sepal Length is :', (df['Petal Width'].max() - df['Petal Width'].min()))
# Out:
# The range of Sepal Length is : 3.6000000000000005
# The range of Sepal Width is : 2.4000000000000004
# The range of Sepal Length is : 5.9
# The range of Sepal Length is : 2.4

# %%
#determine Median of all the dataset
Sepal_Length = sorted(df['Sepal Length'])
Sepal_Width = sorted(df['Sepal Width'])
Petal_Length = sorted(df['Petal Length'])
Petal_Width = sorted(df['Petal Width'])

#print out the median of all the datasets
print('Median of Sepal Length is : ' , median(Sepal_Length))
print('Median of Sepal Width is : ' , median(Sepal_Width))
print('Median of Petal Length is : ' , median(Petal_Length))
print('Median of Petal Width is : ' , median(Petal_Width))
# Out:
# Median of Sepal Length is :  5.8
# Median of Sepal Width is :  3.0
# Median of Petal Length is :  4.35
# Median of Petal Width is :  1.3

# %%
#variance of all the datasets
df.var()
# Out:
# Sepal Length    0.685694
# Sepal Width     0.188004
# Petal Length    3.113179
# Petal Width     0.582414
# dtype: float64

# %%
#determine the min and max value of each feature
print(df.max())
print(df.min())
# Out:
# Sepal Length               7.9
# Sepal Width                4.4
# Petal Length               6.9
# Petal Width                2.5
# Name            Iris-virginica
# dtype: object
# Sepal Length            4.3
# Sepal Width               2
# Petal Length              1
# Petal Width             0.1
# Name            Iris-setosa
# dtype: object

# %%
#let's list what are the unique name and print to list
df['Name'].unique().tolist()
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# # Histogram

# %% [raw]
# 6.4 Create a histogram for each feature in the dataset to illustrate the feature distributions, using the default number of bins

# %%
#histogram with a defualt value of bin 10
df.hist(bins=10)
plt.show()

# %% [markdown]
# # Seaborn with Histogram

# %%
#comparing Iris-setosa,  Iris-versicolor and Iris-virginicafor Sepal Length using histogram
# i use df.loc[df['Name'] == 'Iris-setosa', 'Sepal Length'] to filter the Name and display the sepal lengeth value
#combines the matplotlib hist function
plt.subplots(figsize=(7,6), dpi=100)
sns.distplot(df.loc[df['Name'] == 'Iris-setosa', 'Sepal Length'] , color="dodgerblue", label="Iris-setosa")
sns.distplot(df.loc[df['Name'] == 'Iris-versicolor', 'Sepal Length'], color="orange", label="Iris-versicolor")
sns.distplot(df.loc[df['Name'] == 'Iris-virginica', 'Sepal Length'] , color="deeppink", label="Iris-virginica")

plt.title('Iris Histogram for Sepal Length')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
#Density Plot
#Iris-setosa,  Iris-versicolor and Iris-virginicafor Sepal Length
#extracting Iris-setosa for sepal length
Iris_setosa_length = df.loc[df['Name'] == 'Iris-setosa', 'Sepal Length']
Iris_setosa_width = df.loc[df['Name'] == 'Iris-setosa', 'Sepal Width']
#extracting Iris-versicolor for sepal length
Iris_versicolor_length = df.loc[df['Name'] == 'Iris-virginica', 'Sepal Length']
Iris_versicolor_width = df.loc[df['Name'] == 'Iris-virginica', 'Sepal Width']
#extracting Iris-virginicafor for sepal length
Iris_virginicafor_length = df.loc[df['Name'] == 'Iris-virginicafor', 'Sepal Length']
Iris_virginicafor_width = df.loc[df['Name'] == 'Iris-virginicafor', 'Sepal Width']

#density plot for Iris-setosa,  Iris-versicolor and Iris-virginicafor of Sepal Length
ax = sns.kdeplot(Iris_setosa_width, Iris_setosa_length, cmap="Reds", shade=True, shade_lowest=False, cbar=True)
ax = sns.kdeplot(Iris_versicolor_width, Iris_versicolor_length, cmap="Blues", shade=True, shade_lowest=False, cbar=True)
#ax = sns.kdeplot(Iris_virginicafor_width, Iris_virginicafor_length, cmap="amber", shade=True, shade_lowest=False, cbar=True)

# %%
#Density Plot
#Iris-setosa,  Iris-versicolor and Iris-virginicafor Sepal Length
Iris_setosa_length = df.loc[df['Name'] == 'Iris-setosa', 'Sepal Length']
Iris_setosa_width = df.loc[df['Name'] == 'Iris-setosa', 'Sepal Width']
Iris_versicolor = df.loc[df['Name'] == 'Iris-virginica', 'Sepal Length']
Iris_virginicafor = df.loc[df['Name'] == 'Iris-virginicafor', 'Sepal Length']

ax = sns.kdeplot(Iris_setosa_width, Iris_setosa_length, cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot(Iris_setosa_width, Iris_setosa_length, cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot(Iris_setosa_width, Iris_setosa_length, cmap="Reds", shade=True, shade_lowest=False)


df = df[['Sepal Length', 'Sepal Width', 'Petal Length','Petal Width']]
x1= df['Sepal Length']
x2 =df['Sepal Width']
x3= df['Petal Length']
x4= df['Petal Width']

ax = sns.kdeplot(x1,x2)
ax = sns.kdeplot(x3,x4)
plt.show()

# %% [markdown]
# # Boxplot

# %% [raw]
# 6.5 Create a boxplot for each feature in the dataset. All of the boxplots will be combined into a single plot.

# %%
#referances https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
boxplot = df.boxplot(column=['Sepal Length', 'Sepal Width', 'Petal Length','Petal Width'])

#another way of ploting box plot is 
#df.plot.box(grid=True)

# %% [markdown]
# # Boxplot with jitter

# %%
#
green_diamond = dict(markerfacecolor='g', marker='D')
df_1 = df[['Sepal Length', 'Sepal Width', 'Petal Length','Petal Width']]

ax = sns.stripplot(data=df_1, color="blue", jitter=0.2, size=2.5)
plt.title("Boxplot with jitter", loc="left")

# Usual boxplot
sns.boxplot(data=df)
plt.show()

# %%
#violin plot this helps to show the dnsity of each features, denser regions of the data are fatter, 
#and sparser thiner in a violin plot
sns.violinplot(x='Name', y='Sepal Length', data=df, size=6)
plt.show()

# %% [markdown]
# # Box plots with custom fill colors

# %%
#Colormaps
from matplotlib import cm
df_1.plot(colormap=cm.cubehelix)
plt.show()

# %%
#Draw an area plot based on datasets
df_1.plot.area(stacked=False)
plt.show()

# %%
#Hexagonal Bin Plot: this is helpful for alternative to scatter plots if your data are too dense to plot each point individually
df.plot.hexbin(x='Sepal Length', y='Sepal Width', gridsize=25)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
# scatter plot random 
x = df['Sepal Length']
y = df['Sepal Width']
#150 is total number of  row of the dataset
N = 150
colors = np.random.rand(N)
# 0 to 15 point radii
area = (20 * np.random.rand(N))**2  
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.scatter(x, y, s=area, c=colors, alpha=0.5)

plt.show()

# %% [markdown]
# # Scatter for Sepal Length and Sepal Width

# %%
#let's take the first two features Sepal Length and Sepal Width to plot Scatter

X = df['Sepal Length']
y = df['Sepal Width']

x_min, x_max = X.min(), X.max() 
y_min, y_max = y.min(), y.max() 

plt.figure(2, figsize=(8, 6))
plt.clf()

# Plot the training points
plt.scatter(X, y, c=y, cmap=plt.cm.Set1,edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
plt.legend(loc='upper right')
plt.title('Sepal Length and Sepal Width') 
plt.show()

# %% [markdown]
# # Scatter Masked

# %%
#Scatter Masked
x = df['Sepal Length']
y = df['Sepal Width']
N = 150
r0 = 0.6

area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x * x + y * y)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
theta = np.arange(2, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))
plt.legend()
plt.show()

# %% [markdown]
# # Visualizing pairwise relationships

# %%
#Visualizing pairwise relationships in a dataset
g = sns.PairGrid(df)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
#pairplot
sns.pairplot(df)
plt.show()

# %%
#pairplot is important in order to shows the bivariate relation between each pair of features
sns.pairplot(df, hue='Name', height=3)
plt.show()

# %% [markdown]
# # Referances

# %% [raw]
# 1. https://matplotlib.org/gallery
# 2. https://matplotlib.org/gallery/lines_bars_and_markers/scatter_masked.html#sphx-glr-gallery-lines-bars-and-markers-scatter-masked-pynp.random.seed(19680801)
# 3. https://seaborn.pydata.org/tutorial/distributions.html
